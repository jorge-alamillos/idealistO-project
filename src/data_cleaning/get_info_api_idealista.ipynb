# %% [markdown]
# ### Este Jupyter contiene los métodos necesarios para llamar a la API de Idealista. El objetivo es extraer las características de los inmuebles en una futura actualización de la aplicación. In progress!!

# %%
#El token ya  no es valido
import base64
base64 = base64.b64encode(bytes("####################", 'utf-8'))
print(base64)
authorization = "Basic ############################"
authorization
# Out:
# b'IyMjIyMjIyMjIyMjIyMjIyMjIyM='
# 'Basic ############################'

# %% [markdown]
# Introducir este comando en la terminal para obtener el Token codificado (el token que se muestra ya no es valido):
#
# curl -X POST -H "Authorization: Basic #############################" -H "Content-Type:application/x-www-form-urlencoded" -d 'grant_type=client_credentials&scope=read' "https://api.idealista.com/oauth/token" -k

# %%
token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTYwMjcxMDk4OCwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMGVlZWJlMDQtOGUzZi00MjBhLTgwNjAtNzYxMTc0NjVmNjNhIiwiY2xpZW50X2lkIjoiemZzbHZ3dDFhNGR0dWN2YTd3MncxMmdma21vOHNidWcifQ.fgUJOpOnC1mhLii0kYM6I_TQ5pc9KIjgqRCNNi-KkcM"

# %%
def gen_url(token,pages):
    urls = list()
    url = f"https://api.idealista.com/3.5/es/search"
    for page in range(pages):
        endpoint = f"?locale=es&operation=sale&propertyType=homes&center=40.416,-3.703&distance=40000&maxitems=50&numPage={page+1}"
        urls.append(url+endpoint)
    return urls

urls = gen_url(token,2)

# %%
import time
import requests
def post_idealista(urls):
    pisos = list()
    headers = {
        "Authorization": token,
        "Content-Type": "application/x-www-form-urlencoded"
    }

    for url in urls:
        for piso  in url:
            pisos.append(requests.post(url,headers=headers).json())
        time.sleep(5.0)
    return pisos    
pisos = post_idealista(urls)

# %%
pisos
# Out:
# [{'elementList': [{'propertyCode': '89778948',
#     'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/53/fa/c4/622518535.jpg',
#     'externalReference': 'p5 1º a',
#     'numPhotos': 10,
#     'floor': '1',
#     'price': 479000.0,
#     'propertyType': 'flat',
#     'operation': 'sale',
#     'size': 146.0,
#     'exterior': True,
#     'rooms': 3,
#     'bathrooms': 2,
#     'address': 'Calle Félix Candela, 47',
#     'province': 'Madrid',
#     'municipality': 'Madrid',
#     'district': 'Hortaleza',
#     'country': 'es',
#     'neighborhood': 'Valdebebas - Valdefuentes',
#     'latitude': 40.4968752,
#     'longitude': -3.6183167,
#     'showAddress': True,
#     'url': 'https://www.idealista.com/obra-nueva/89778948/',
#     'distance': '11497',
#     'hasVideo': False,
#     'status': 'newdevelopment',
#     'newDevelopment': True,
#     'hasLift': True,
#     'newDevelopmentFinished': False,
#     'priceByArea': 3281.0,
# ...

# %%
import requests
headers = {
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTYwMjUyOTAwMiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiM2ViMDc3ODctNWM5NS00OGE1LTg0ZDAtZDgyNGIxNTI4Y2JjIiwiY2xpZW50X2lkIjoiemZzbHZ3dDFhNGR0dWN2YTd3MncxMmdma21vOHNidWcifQ.rxgr7gDfQOl8oLL43_BdpmwsCMSQ8ehLDwOmtLiVTJI",
        "Content-Type": "application/x-www-form-urlencoded"
    }

response = requests.post('https://api.idealista.com/3.5/es/search?locale=es&operation=sale&propertyType=homes&center=40.416,-3.703&distance=3000&maxitems=50&numPage=1',headers=headers)
response
# Out:
# <Response [429]>

# %%
response.headers
# Out:
# {'server': 'idealista', 'date': 'Thu, 08 Oct 2020 08:30:29 GMT', 'content-type': 'application/json;charset=UTF-8', 'transfer-encoding': 'chunked', 'set-cookie': 'APIPUBID=3d5ed4374026f476|X37OF|X37OF; path=/; HttpOnly; Secure'}
